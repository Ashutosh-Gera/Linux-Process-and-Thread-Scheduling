# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

x = ["SCHED FIFO", "SCHED RR", "SCHED OTHER"]
y = [25, 26.5, 27.2]

fig = plt.figure(figsize = (10, 6))
plt.bar(x, y)
# plt.legend(["Thread A", "Thread B","Thread C"], size=6)
plt.title("Priority Values vs Time plot", fontsize=25)
plt.xlabel("Scheduling Policy", fontsize=25)
plt.ylabel("Time", fontsize=25)
plt.show()
